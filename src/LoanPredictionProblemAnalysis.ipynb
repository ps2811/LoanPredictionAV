# %% [markdown]
# ## Loan Prediction Problem
# We will try to write a simple classifier solving loan prediction problem.

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('../data/train.csv')
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#Summary
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#Seems to have missing values
train.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Need to deal with the columns having missing values.

# %%
#Replace with mode ?
#Repalce with median ?
#Replace with special value ?
#Use ifelse to replace values based on value of other column ?

# %%
#Load test file 
test = pd.read_csv('../data/test.csv')
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
test.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#Combining train and test files
train['flag'] = 'train'
test['flag'] = 'test'

data=pd.concat([train, test],ignore_index=True)
data.shape
# Out:
# (981, 14)

# %%
data.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0             5849                0.0             1.0          0
# 1             4583             1508.0             1.0          1
# 2             3000                0.0             1.0          0
# 3             2583             2358.0             1.0          0
# 4             6000                0.0             1.0          0
#
#       Education Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0      Graduate   Male         NaN             360.0  LP001002           Y
# 1      Graduate   Male       128.0             360.0  LP001003           N
# 2      Graduate   Male        66.0             360.0  LP001005           Y
# 3  Not Graduate   Male       120.0             360.0  LP001006           Y
# 4      Graduate   Male       141.0             360.0  LP001008           Y
#
#   Married Property_Area Self_Employed   flag
# 0      No         Urban            No  train
# ...

# %%
data.isna().sum()
# Out:
# ApplicantIncome        0
# CoapplicantIncome      0
# Credit_History        79
# Dependents            25
# Education              0
# Gender                24
# LoanAmount            27
# Loan_Amount_Term      20
# Loan_ID                0
# Loan_Status          367
# Married                3
# Property_Area          0
# Self_Employed         55
# flag                   0
# dtype: int64
